# %% [markdown]
# **Mengimport Library yang dibutuhkan**

# %%
# Mengimpor library yang diperlukan
from sklearn.neighbors import RadiusNeighborsClassifier
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Memuat Data**

# %%
# Memuat dataset 
data = pd.read_csv('train.csv')
data.sample(10) #Menampilkan 10 sample dari train.csv
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory
# 1787           1830     1          1.0         0   7       1          47  \
# 1650           1948     0          2.9         1   4       0           5
# 312             894     0          0.5         1   1       1          50
# 562            1758     1          0.5         0  11       1          13
# 1708           1849     1          0.5         0   1       0          29
# 1632           1362     1          2.9         0   0       0          47
# 304            1177     0          0.9         0   1       1          29
# 1270           1053     0          2.9         0   7       0          42
# 1189            511     0          0.7         1   1       1          52
# 297            1329     1          1.0         0   1       0          52
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w
# 1787    0.3        117        1  ...       1191      1882  3362    13    10  \
# ...

# %% [markdown]
# **Memilih Fitur**

# %%
data.columns #Disini semua column digunakan
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# **Mencari Data Yang Hilang**

# %%
#Disini akan mengecek apakah ada Data yang hilang
df = pd.DataFrame(data)

# Mendeteksi missing value dalam DataFrame
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# **Menghapus Data yang tidak relevan**

# %% [markdown]
# Tidak ada data yang tidak relevan

# %% [markdown]
# **Mengubah Data kategorikal menjadi numerik**

# %%
data.dtypes  #Cek tipe data
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %% [markdown]
# Semua data sudah dalam bentuk tipe data numerik

# %% [markdown]
# **Normalisasi**
# <br>
# tidak perlu

# %% [markdown]
# **Memisahkan Data menjadi set pelatihan dan pengujian**

# %% [markdown]
# **Menangani data yang tidak seimbang**

# %% [markdown]
# **Split dataset menjadi dua yaitu menjadi data train dan data test**

# %%
# Membuat objek Radius Neighbors Classifier
radius = 0.7  # Nilai radius yang diinginkan
clf = RadiusNeighborsClassifier(radius=radius)

#Split Dataset 
X = data.drop('price_range',axis = 1)
y = data['price_range']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# Menyimpan model RadiusNeighbors ke file menggunakan joblib
joblib.dump(clf, 'radiusneighbors_model.pkl')

# Menampilkan pesan setelah menyimpan model
print("Model Radius Neighbors telah disimpan")
# Out:
# Model Radius Neighbors telah disimpan
